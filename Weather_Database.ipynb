# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 2. Generate a new set of 1,500 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\lrinc\anaconda3\lib\site-packages (0.0.5)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: kdtree>=0.12 in c:\users\lrinc\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# 3. Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 588

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# 4. Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39af99da03d082a40bbeea7bd6a0f6ef

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# 5. Retrieve the following information from the API call:
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        try:
            rain_inches = city_weather["rain"]["1h"]
        except:
            rain_inches = ("0")
            pass
        try:
            snow_inches = city_weather["snow"]["1h"]
        except:
            snow_inches = ("0")
            pass
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description,
                          "Rain (inches)": rain_inches,
                          "Snow (inches)": snow_inches})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kalmunai
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | coihaique
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | manakara
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | pakxan
# Processing Record 10 of Set 1 | acapulco
# Processing Record 11 of Set 1 | pevek
# Processing Record 12 of Set 1 | matara
# Processing Record 13 of Set 1 | jambi
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | narsaq
# Processing Record 16 of Set 1 | avera
# Processing Record 17 of Set 1 | yulara
# Processing Record 18 of Set 1 | tautira
# Processing Record 19 of Set 1 | nyurba
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | mount gambier
# Processing Record 22 of Set 1 | clonmel
# Processing Record 23 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | luderitz
# Processing Record 26 of Set 1 | malakal
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | pisco
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | kankon
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | touros
# Processing Record 33 of Set 1 | sorong
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 1 | laguna
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | matagami
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | vardo
# Processing Record 42 of Set 1 | luebo
# Processing Record 43 of Set 1 | mareeba
# Processing Record 44 of Set 1 | saint-francois
# Processing Record 45 of Set 1 | jadu
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | krasnoselkup
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | morant bay
# Processing Record 1 of Set 2 | yomitan
# City not found. Skipping...
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 2 | saint-pierre
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | saint-philippe
# Processing Record 6 of Set 2 | sao filipe
# Processing Record 7 of Set 2 | hualmay
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | hvolsvollur
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | hay river
# Processing Record 12 of Set 2 | sitka
# Processing Record 13 of Set 2 | quelimane
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | timbiqui
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | lyskovo
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | dinghai
# Processing Record 22 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 23 of Set 2 | belfast
# Processing Record 24 of Set 2 | porto novo
# Processing Record 25 of Set 2 | kenai
# Processing Record 26 of Set 2 | saint-augustin
# Processing Record 27 of Set 2 | porto belo
# Processing Record 28 of Set 2 | vostok
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | palmer
# Processing Record 31 of Set 2 | stalowa wola
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | severo-kurilsk
# Processing Record 34 of Set 2 | ostrovnoy
# Processing Record 35 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | batagay-alyta
# Processing Record 38 of Set 2 | tagab
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | pozo colorado
# Processing Record 41 of Set 2 | bengkulu
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | grindavik
# Processing Record 44 of Set 2 | souillac
# Processing Record 45 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 2 | roald
# Processing Record 47 of Set 2 | kavieng
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 50 of Set 2 | fort nelson
# Processing Record 1 of Set 3 | krasnoye
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | ngunguru
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | celestun
# Processing Record 8 of Set 3 | san cristobal
# Processing Record 9 of Set 3 | chelyabinsk-70
# City not found. Skipping...
# Processing Record 10 of Set 3 | apatity
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | ciudad bolivar
# Processing Record 14 of Set 3 | andros town
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | tuy hoa
# Processing Record 18 of Set 3 | ketchikan
# Processing Record 19 of Set 3 | egvekinot
# Processing Record 20 of Set 3 | chinsali
# Processing Record 21 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | mar del plata
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | plerin
# Processing Record 26 of Set 3 | pirovskoye
# Processing Record 27 of Set 3 | morondava
# Processing Record 28 of Set 3 | westport
# Processing Record 29 of Set 3 | isangel
# Processing Record 30 of Set 3 | adrar
# Processing Record 31 of Set 3 | uaua
# Processing Record 32 of Set 3 | dasoguz
# Processing Record 33 of Set 3 | tadepallegudem
# Processing Record 34 of Set 3 | norman wells
# Processing Record 35 of Set 3 | derzhavinsk
# Processing Record 36 of Set 3 | takaungu
# Processing Record 37 of Set 3 | gijon
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | cidreira
# Processing Record 40 of Set 3 | green river
# Processing Record 41 of Set 3 | tungi
# Processing Record 42 of Set 3 | chokurdakh
# Processing Record 43 of Set 3 | roswell
# Processing Record 44 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | te anau
# Processing Record 46 of Set 3 | gat
# Processing Record 47 of Set 3 | rock sound
# Processing Record 48 of Set 3 | searcy
# Processing Record 49 of Set 3 | la palma
# Processing Record 50 of Set 3 | palana
# Processing Record 1 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 4 | alugan
# Processing Record 3 of Set 4 | dingle
# Processing Record 4 of Set 4 | port-gentil
# Processing Record 5 of Set 4 | arman
# Processing Record 6 of Set 4 | tilichiki
# Processing Record 7 of Set 4 | a
# City not found. Skipping...
# Processing Record 8 of Set 4 | lethem
# Processing Record 9 of Set 4 | sao joao da barra
# Processing Record 10 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 4 | pangkalanbuun
# Processing Record 14 of Set 4 | perigueux
# Processing Record 15 of Set 4 | vitim
# Processing Record 16 of Set 4 | riyadh
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | bamako
# Processing Record 19 of Set 4 | bandarbeyla
# Processing Record 20 of Set 4 | alta floresta
# Processing Record 21 of Set 4 | henties bay
# Processing Record 22 of Set 4 | torbay
# Processing Record 23 of Set 4 | narasannapeta
# Processing Record 24 of Set 4 | sumbe
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | vestmannaeyjar
# Processing Record 27 of Set 4 | linhares
# Processing Record 28 of Set 4 | almeirim
# Processing Record 29 of Set 4 | barabai
# Processing Record 30 of Set 4 | mana
# Processing Record 31 of Set 4 | andenes
# Processing Record 32 of Set 4 | mehamn
# Processing Record 33 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 4 | troitsko-pechorsk
# Processing Record 36 of Set 4 | carnarvon
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | teguise
# Processing Record 39 of Set 4 | urubicha
# Processing Record 40 of Set 4 | farsund
# Processing Record 41 of Set 4 | hanmer springs
# Processing Record 42 of Set 4 | svetlogorsk
# Processing Record 43 of Set 4 | opuwo
# Processing Record 44 of Set 4 | yellowknife
# Processing Record 45 of Set 4 | hilo
# Processing Record 46 of Set 4 | murgab
# Processing Record 47 of Set 4 | hasaki
# Processing Record 48 of Set 4 | guia de isora
# Processing Record 49 of Set 4 | tolaga bay
# Processing Record 50 of Set 4 | makakilo city
# Processing Record 1 of Set 5 | luganville
# Processing Record 2 of Set 5 | iranshahr
# Processing Record 3 of Set 5 | katsuura
# Processing Record 4 of Set 5 | vila
# Processing Record 5 of Set 5 | canala
# Processing Record 6 of Set 5 | san quintin
# Processing Record 7 of Set 5 | bartica
# Processing Record 8 of Set 5 | nara
# Processing Record 9 of Set 5 | port macquarie
# Processing Record 10 of Set 5 | olafsvik
# Processing Record 11 of Set 5 | tabuk
# Processing Record 12 of Set 5 | sambava
# Processing Record 13 of Set 5 | kruisfontein
# Processing Record 14 of Set 5 | mahibadhoo
# Processing Record 15 of Set 5 | abu kamal
# Processing Record 16 of Set 5 | golden
# Processing Record 17 of Set 5 | moshenskoye
# Processing Record 18 of Set 5 | klaksvik
# Processing Record 19 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 5 | tahta
# Processing Record 21 of Set 5 | salalah
# Processing Record 22 of Set 5 | prince rupert
# Processing Record 23 of Set 5 | tripoli
# Processing Record 24 of Set 5 | ancud
# Processing Record 25 of Set 5 | east london
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | camacha
# Processing Record 28 of Set 5 | nanortalik
# Processing Record 29 of Set 5 | casper
# Processing Record 30 of Set 5 | port blair
# Processing Record 31 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 5 | cabo san lucas
# Processing Record 33 of Set 5 | roebourne
# Processing Record 34 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 5 | belyy yar
# Processing Record 36 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 5 | yerbogachen
# Processing Record 38 of Set 5 | verkhnevilyuysk
# Processing Record 39 of Set 5 | pemberton
# Processing Record 40 of Set 5 | tasiilaq
# Processing Record 41 of Set 5 | college
# Processing Record 42 of Set 5 | bafq
# Processing Record 43 of Set 5 | naica
# Processing Record 44 of Set 5 | jackson
# Processing Record 45 of Set 5 | fez
# Processing Record 46 of Set 5 | dumraon
# Processing Record 47 of Set 5 | tchibanga
# Processing Record 48 of Set 5 | jibuti
# Processing Record 49 of Set 5 | iqaluit
# Processing Record 50 of Set 5 | mwene-ditu
# Processing Record 1 of Set 6 | saint anthony
# Processing Record 2 of Set 6 | tuatapere
# Processing Record 3 of Set 6 | glace bay
# Processing Record 4 of Set 6 | airai
# Processing Record 5 of Set 6 | moerai
# Processing Record 6 of Set 6 | kokkola
# Processing Record 7 of Set 6 | caapucu
# Processing Record 8 of Set 6 | kahului
# Processing Record 9 of Set 6 | minab
# Processing Record 10 of Set 6 | tucumcari
# Processing Record 11 of Set 6 | samarai
# Processing Record 12 of Set 6 | horasan
# Processing Record 13 of Set 6 | bambanglipuro
# Processing Record 14 of Set 6 | yelovo
# Processing Record 15 of Set 6 | surt
# Processing Record 16 of Set 6 | carberry
# Processing Record 17 of Set 6 | kytlym
# City not found. Skipping...
# Processing Record 18 of Set 6 | kalabo
# Processing Record 19 of Set 6 | santa isabel do rio negro
# Processing Record 20 of Set 6 | codrington
# Processing Record 21 of Set 6 | westerland
# Processing Record 22 of Set 6 | hami
# Processing Record 23 of Set 6 | tazovskiy
# Processing Record 24 of Set 6 | changli
# Processing Record 25 of Set 6 | rio grande
# Processing Record 26 of Set 6 | walvis bay
# Processing Record 27 of Set 6 | ilulissat
# Processing Record 28 of Set 6 | bilibino
# Processing Record 29 of Set 6 | itanhem
# Processing Record 30 of Set 6 | muros
# Processing Record 31 of Set 6 | geraldton
# Processing Record 32 of Set 6 | komsomolskiy
# Processing Record 33 of Set 6 | mnogovershinnyy
# Processing Record 34 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 6 | ixtapa
# Processing Record 36 of Set 6 | candolim
# Processing Record 37 of Set 6 | tecoanapa
# Processing Record 38 of Set 6 | shingu
# Processing Record 39 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 6 | preston
# Processing Record 41 of Set 6 | butembo
# Processing Record 42 of Set 6 | arraial do cabo
# Processing Record 43 of Set 6 | glendive
# Processing Record 44 of Set 6 | brus laguna
# Processing Record 45 of Set 6 | gwadar
# Processing Record 46 of Set 6 | araouane
# Processing Record 47 of Set 6 | san andres
# Processing Record 48 of Set 6 | marsh harbour
# Processing Record 49 of Set 6 | dakar
# Processing Record 50 of Set 6 | ambon
# Processing Record 1 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 7 | castro
# Processing Record 3 of Set 7 | ferme-neuve
# Processing Record 4 of Set 7 | camrose
# Processing Record 5 of Set 7 | babstovo
# Processing Record 6 of Set 7 | rozsypne
# Processing Record 7 of Set 7 | ialibu
# Processing Record 8 of Set 7 | kaohsiung
# Processing Record 9 of Set 7 | calama
# Processing Record 10 of Set 7 | karpogory
# Processing Record 11 of Set 7 | kungurtug
# Processing Record 12 of Set 7 | kamenka
# Processing Record 13 of Set 7 | abu samrah
# Processing Record 14 of Set 7 | peterborough
# Processing Record 15 of Set 7 | vao
# Processing Record 16 of Set 7 | arezzo
# Processing Record 17 of Set 7 | heilbad heiligenstadt
# Processing Record 18 of Set 7 | provideniya
# Processing Record 19 of Set 7 | dunedin
# Processing Record 20 of Set 7 | srednekolymsk
# Processing Record 21 of Set 7 | bara
# Processing Record 22 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 7 | victoria
# Processing Record 24 of Set 7 | ponta delgada
# Processing Record 25 of Set 7 | lagoa
# Processing Record 26 of Set 7 | quzhou
# Processing Record 27 of Set 7 | port hedland
# Processing Record 28 of Set 7 | atasu
# Processing Record 29 of Set 7 | caohe
# Processing Record 30 of Set 7 | guerande
# Processing Record 31 of Set 7 | yumen
# Processing Record 32 of Set 7 | ternate
# Processing Record 33 of Set 7 | cherskiy
# Processing Record 34 of Set 7 | high rock
# Processing Record 35 of Set 7 | kununurra
# Processing Record 36 of Set 7 | lexington park
# Processing Record 37 of Set 7 | hammerfest
# Processing Record 38 of Set 7 | rocha
# Processing Record 39 of Set 7 | bathsheba
# Processing Record 40 of Set 7 | maraa
# Processing Record 41 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 7 | mayya
# Processing Record 43 of Set 7 | luanda
# Processing Record 44 of Set 7 | lompoc
# Processing Record 45 of Set 7 | lorengau
# Processing Record 46 of Set 7 | bulgan
# Processing Record 47 of Set 7 | kankan
# Processing Record 48 of Set 7 | benghazi
# Processing Record 49 of Set 7 | husavik
# Processing Record 50 of Set 7 | caticlan
# Processing Record 1 of Set 8 | burnie
# Processing Record 2 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 8 | rio cuarto
# Processing Record 4 of Set 8 | saint george
# Processing Record 5 of Set 8 | saldanha
# Processing Record 6 of Set 8 | asau
# Processing Record 7 of Set 8 | san rafael
# Processing Record 8 of Set 8 | iquique
# Processing Record 9 of Set 8 | guerrero negro
# Processing Record 10 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 8 | richards bay
# Processing Record 12 of Set 8 | anloga
# Processing Record 13 of Set 8 | kalangala
# Processing Record 14 of Set 8 | alofi
# Processing Record 15 of Set 8 | severnoye
# Processing Record 16 of Set 8 | kavaratti
# Processing Record 17 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 8 | kloulklubed
# Processing Record 19 of Set 8 | havre-saint-pierre
# Processing Record 20 of Set 8 | the valley
# Processing Record 21 of Set 8 | leningradskiy
# Processing Record 22 of Set 8 | durres
# Processing Record 23 of Set 8 | bagdarin
# Processing Record 24 of Set 8 | frisco
# Processing Record 25 of Set 8 | mabaruma
# Processing Record 26 of Set 8 | zhigansk
# Processing Record 27 of Set 8 | nouadhibou
# Processing Record 28 of Set 8 | middelburg
# Processing Record 29 of Set 8 | tabory
# Processing Record 30 of Set 8 | nouakchott
# Processing Record 31 of Set 8 | montes altos
# Processing Record 32 of Set 8 | leshan
# Processing Record 33 of Set 8 | kirkwood
# Processing Record 34 of Set 8 | uroteppa
# City not found. Skipping...
# Processing Record 35 of Set 8 | cavalcante
# Processing Record 36 of Set 8 | terney
# Processing Record 37 of Set 8 | champasak
# Processing Record 38 of Set 8 | pirenopolis
# Processing Record 39 of Set 8 | ibicarai
# Processing Record 40 of Set 8 | aswan
# Processing Record 41 of Set 8 | baghdad
# Processing Record 42 of Set 8 | luba
# Processing Record 43 of Set 8 | puerto cabezas
# Processing Record 44 of Set 8 | paamiut
# Processing Record 45 of Set 8 | daru
# Processing Record 46 of Set 8 | gorgan
# Processing Record 47 of Set 8 | kirakira
# Processing Record 48 of Set 8 | nanzhou
# Processing Record 49 of Set 8 | kuva
# City not found. Skipping...
# Processing Record 50 of Set 8 | fairbanks
# Processing Record 1 of Set 9 | coihueco
# Processing Record 2 of Set 9 | port moresby
# Processing Record 3 of Set 9 | novozavedennoye
# Processing Record 4 of Set 9 | tarko-sale
# Processing Record 5 of Set 9 | atbasar
# Processing Record 6 of Set 9 | nemuro
# Processing Record 7 of Set 9 | broome
# Processing Record 8 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 9 of Set 9 | saint-omer
# Processing Record 10 of Set 9 | batagay
# Processing Record 11 of Set 9 | usinsk
# Processing Record 12 of Set 9 | bambous virieux
# Processing Record 13 of Set 9 | lufilufi
# Processing Record 14 of Set 9 | zlitan
# Processing Record 15 of Set 9 | juneau
# Processing Record 16 of Set 9 | san patricio
# Processing Record 17 of Set 9 | sabha
# Processing Record 18 of Set 9 | masuguru
# Processing Record 19 of Set 9 | munchenbuchsee
# Processing Record 20 of Set 9 | tual
# Processing Record 21 of Set 9 | puerto pinasco
# City not found. Skipping...
# Processing Record 22 of Set 9 | lavrentiya
# Processing Record 23 of Set 9 | esmeraldas
# Processing Record 24 of Set 9 | cairns
# Processing Record 25 of Set 9 | ahipara
# Processing Record 26 of Set 9 | bourail
# Processing Record 27 of Set 9 | ribeira brava
# Processing Record 28 of Set 9 | govindgarh
# Processing Record 29 of Set 9 | same
# Processing Record 30 of Set 9 | chicama
# Processing Record 31 of Set 9 | tampere
# Processing Record 32 of Set 9 | xadani
# City not found. Skipping...
# Processing Record 33 of Set 9 | saint-denis
# Processing Record 34 of Set 9 | boddam
# Processing Record 35 of Set 9 | la ronge
# Processing Record 36 of Set 9 | florianopolis
# Processing Record 37 of Set 9 | cockburn town
# Processing Record 38 of Set 9 | bryanka
# Processing Record 39 of Set 9 | atar
# Processing Record 40 of Set 9 | bissen
# Processing Record 41 of Set 9 | madison
# Processing Record 42 of Set 9 | maniitsoq
# Processing Record 43 of Set 9 | jijiga
# Processing Record 44 of Set 9 | mariestad
# Processing Record 45 of Set 9 | zhuhai
# Processing Record 46 of Set 9 | kutum
# Processing Record 47 of Set 9 | bac lieu
# Processing Record 48 of Set 9 | babushkin
# Processing Record 49 of Set 9 | vanimo
# Processing Record 50 of Set 9 | manaus
# Processing Record 1 of Set 10 | huarmey
# Processing Record 2 of Set 10 | dormidontovka
# Processing Record 3 of Set 10 | karratha
# Processing Record 4 of Set 10 | santa fe
# Processing Record 5 of Set 10 | antalaha
# Processing Record 6 of Set 10 | okha
# Processing Record 7 of Set 10 | caucaia
# Processing Record 8 of Set 10 | ambovombe
# Processing Record 9 of Set 10 | malartic
# Processing Record 10 of Set 10 | port hardy
# Processing Record 11 of Set 10 | beloha
# Processing Record 12 of Set 10 | mitsamiouli
# Processing Record 13 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 10 | talnakh
# Processing Record 15 of Set 10 | kathmandu
# Processing Record 16 of Set 10 | nome
# Processing Record 17 of Set 10 | hirara
# Processing Record 18 of Set 10 | portland
# Processing Record 19 of Set 10 | hornepayne
# Processing Record 20 of Set 10 | qui nhon
# Processing Record 21 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 22 of Set 10 | somerset west
# Processing Record 23 of Set 10 | tessalit
# Processing Record 24 of Set 10 | awjilah
# Processing Record 25 of Set 10 | valparaiso
# Processing Record 26 of Set 10 | xichang
# Processing Record 27 of Set 10 | torbat-e jam
# Processing Record 28 of Set 10 | oranjestad
# Processing Record 29 of Set 10 | pandoh
# Processing Record 30 of Set 10 | hofn
# Processing Record 31 of Set 10 | abha
# Processing Record 32 of Set 10 | doka
# Processing Record 33 of Set 10 | bastrop
# Processing Record 34 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 35 of Set 10 | gavle
# Processing Record 36 of Set 10 | aklavik
# Processing Record 37 of Set 10 | decatur
# Processing Record 38 of Set 10 | lasa
# Processing Record 39 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 40 of Set 10 | pahrump
# Processing Record 41 of Set 10 | palia kalan
# Processing Record 42 of Set 10 | galchino
# City not found. Skipping...
# Processing Record 43 of Set 10 | clyde river
# Processing Record 44 of Set 10 | berlevag
# Processing Record 45 of Set 10 | baijiantan
# Processing Record 46 of Set 10 | zhongxing
# Processing Record 47 of Set 10 | ures
# Processing Record 48 of Set 10 | constitucion
# Processing Record 49 of Set 10 | nuevo progreso
# Processing Record 50 of Set 10 | faanui
# Processing Record 1 of Set 11 | navapur
# City not found. Skipping...
# Processing Record 2 of Set 11 | general salgado
# Processing Record 3 of Set 11 | imphal
# Processing Record 4 of Set 11 | liverpool
# Processing Record 5 of Set 11 | quepos
# Processing Record 6 of Set 11 | changde
# Processing Record 7 of Set 11 | livramento
# Processing Record 8 of Set 11 | kikinda
# Processing Record 9 of Set 11 | ambilobe
# Processing Record 10 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 11 of Set 11 | stromness
# Processing Record 12 of Set 11 | synya
# Processing Record 13 of Set 11 | ourossogui
# Processing Record 14 of Set 11 | kurilsk
# Processing Record 15 of Set 11 | neiafu
# Processing Record 16 of Set 11 | saraland
# Processing Record 17 of Set 11 | zastavna
# Processing Record 18 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 11 | buta
# Processing Record 20 of Set 11 | sebastian
# Processing Record 21 of Set 11 | cap-chat
# Processing Record 22 of Set 11 | southbridge
# Processing Record 23 of Set 11 | ballina
# Processing Record 24 of Set 11 | marawi
# Processing Record 25 of Set 11 | rawson
# Processing Record 26 of Set 11 | parabel
# Processing Record 27 of Set 11 | thunder bay
# Processing Record 28 of Set 11 | urumqi
# Processing Record 29 of Set 11 | tiksi
# Processing Record 30 of Set 11 | prado
# Processing Record 31 of Set 11 | kedrovyy
# Processing Record 32 of Set 11 | harper
# Processing Record 33 of Set 11 | zhigalovo
# Processing Record 34 of Set 11 | hambantota
# Processing Record 35 of Set 11 | peruibe
# Processing Record 36 of Set 11 | alvorada
# Processing Record 37 of Set 11 | koumac
# Processing Record 38 of Set 11 | kawalu
# Processing Record 39 of Set 11 | vuktyl
# Processing Record 40 of Set 11 | san lorenzo
# Processing Record 41 of Set 11 | vila franca do campo
# Processing Record 42 of Set 11 | biak
# Processing Record 43 of Set 11 | tabou
# Processing Record 44 of Set 11 | novopskov
# Processing Record 45 of Set 11 | jiaojiang
# Processing Record 46 of Set 11 | fortuna
# Processing Record 47 of Set 11 | coquimbo
# Processing Record 48 of Set 11 | saurimo
# Processing Record 49 of Set 11 | artyom
# Processing Record 50 of Set 11 | shkotovo
# Processing Record 1 of Set 12 | bintulu
# Processing Record 2 of Set 12 | cambre
# Processing Record 3 of Set 12 | sanda
# Processing Record 4 of Set 12 | carndonagh
# Processing Record 5 of Set 12 | havelock
# Processing Record 6 of Set 12 | madimba
# Processing Record 7 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 8 of Set 12 | puerto escondido
# Processing Record 9 of Set 12 | sur
# Processing Record 10 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 12 | tocopilla
# Processing Record 12 of Set 12 | poso
# Processing Record 13 of Set 12 | flin flon
# Processing Record 14 of Set 12 | margate
# Processing Record 15 of Set 12 | repcelak
# Processing Record 16 of Set 12 | plouzane
# Processing Record 17 of Set 12 | linqing
# Processing Record 18 of Set 12 | fukue
# Processing Record 19 of Set 12 | candido de abreu
# Processing Record 20 of Set 12 | medea
# Processing Record 21 of Set 12 | nampula
# Processing Record 22 of Set 12 | great yarmouth
# Processing Record 23 of Set 12 | namatanai
# Processing Record 24 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 25 of Set 12 | malm
# Processing Record 26 of Set 12 | penzance
# Processing Record 27 of Set 12 | bonthe
# Processing Record 28 of Set 12 | ormstown
# Processing Record 29 of Set 12 | porto santo
# Processing Record 30 of Set 12 | magangue
# Processing Record 31 of Set 12 | desaguadero
# Processing Record 32 of Set 12 | davila
# Processing Record 33 of Set 12 | inhambane
# Processing Record 34 of Set 12 | grand gaube
# Processing Record 35 of Set 12 | pangnirtung
# Processing Record 36 of Set 12 | namibe
# Processing Record 37 of Set 12 | carlyle
# Processing Record 38 of Set 12 | pouembout
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 6. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kalmunai      LK   7.42   81.82     84.87        69          95
# 1        Albany      US  42.60  -73.97     71.01        71          39
# 2     Coihaique      CL -45.58  -72.07     30.20        92          75
# 3        Atuona      PF  -9.80 -139.03     79.77        75           8
# 4      Manakara      MG -22.13   48.02     64.04        90           1
# 5  Longyearbyen      SJ  78.22   15.64     44.60        81          75
# 6        Dikson      RU  73.51   80.55     40.15        91          98
# 7        Pakxan      LA  18.38  103.66     87.39        67          44
# 8      Acapulco      MX  16.86  -99.89     84.20        79          40
# 9         Pevek      RU  69.70  170.31     41.72        77          22
#
#    Wind Speed Current Description Rain (inches) Snow (inches)
# 0       11.86     overcast clouds             0             0
# 1        2.71    scattered clouds             0             0
# 2        3.36       broken clouds             0             0
# 3       18.68           clear sky             0             0
# 4        2.89           clear sky             0             0
# 5        5.82       broken clouds             0             0
# 6       13.40     overcast clouds             0             0
# 7        2.62       moderate rain          1.38             0
# 8        4.70    scattered clouds             0             0
# 9        6.33          few clouds             0             0

# %%
# 7. Save the new DataFrame as a CSV file to be used for Part 2.
output_data_file = "weather_database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
